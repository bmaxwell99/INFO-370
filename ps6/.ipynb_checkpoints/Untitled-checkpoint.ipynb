# %%
# %run initial_data_cleaning.ipynb

import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
test = data[['price', 'bedrooms']]
test.dropna()

m = smf.ols(formula = 'price ~ bedrooms', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     697.3
# Date:                Sat, 30 Nov 2019   Prob (F-statistic):          4.72e-147
# Time:                        16:56:38   Log-Likelihood:                -50118.
# No. Observations:                7539   AIC:                         1.002e+05
# Df Residuals:                    7537   BIC:                         1.003e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     93.3393      3.613     25.837      0.000      86.258     100.421
# bedrooms      55.5599      2.104     26.407      0.000      51.436      59.684
# ==============================================================================
# Omnibus:                    11364.243   Durbin-Watson:                   1.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9442766.444
# Skew:                           9.060   Prob(JB):                         0.00
# Kurtosis:                     175.430   Cond. No.                         3.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
test = data[['price', 'host_is_superhost']]
test.dropna()

m = smf.ols(formula = 'price ~ host_is_superhost', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     95.59
# Date:                Sat, 30 Nov 2019   Prob (F-statistic):           1.92e-22
# Time:                        17:05:01   Log-Likelihood:                -50410.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7538   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           188.5566      2.929     64.372      0.000     182.815     194.299
# host_is_superhost   -44.2243      4.523     -9.777      0.000     -53.091     -35.357
# ==============================================================================
# Omnibus:                    10875.441   Durbin-Watson:                   1.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7620957.073
# Skew:                           8.328   Prob(JB):                         0.00
# Kurtosis:                     157.856   Cond. No.                         2.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
test = data[['price', 'bedrooms', 'host_is_superhost']]
test.dropna()

m = smf.ols(formula = 'price ~ host_is_superhost  + bedrooms ', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     403.1
# Date:                Sat, 30 Nov 2019   Prob (F-statistic):          4.73e-167
# Time:                        16:57:40   Log-Likelihood:                -50068.
# No. Observations:                7539   AIC:                         1.001e+05
# Df Residuals:                    7536   BIC:                         1.002e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           111.7241      4.034     27.698      0.000     103.817     119.631
# host_is_superhost   -43.2184      4.327     -9.988      0.000     -51.701     -34.736
# bedrooms             55.3728      2.090     26.489      0.000      51.275      59.471
# ==============================================================================
# Omnibus:                    11402.378   Durbin-Watson:                   1.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9885686.411
# Skew:                           9.106   Prob(JB):                         0.00
# Kurtosis:                     179.462   Cond. No.                         4.69
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
test = data[['price', 'beds']]
test.dropna()

m = smf.ols(formula = 'price ~ beds', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     453.7
# Date:                Sat, 30 Nov 2019   Prob (F-statistic):           8.12e-98
# Time:                        17:01:39   Log-Likelihood:                -50218.
# No. Observations:                7537   AIC:                         1.004e+05
# Df Residuals:                    7535   BIC:                         1.005e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    113.2235      3.446     32.854      0.000     106.468     119.979
# beds          29.7658      1.397     21.301      0.000      27.027      32.505
# ==============================================================================
# Omnibus:                    11144.423   Durbin-Watson:                   1.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8894306.682
# Skew:                           8.715   Prob(JB):                         0.00
# Kurtosis:                     170.387   Cond. No.                         4.30
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
test = data[['price', 'review_scores_rating']]
test.dropna()

m = smf.ols(formula = 'price ~ review_scores_rating', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Sat, 30 Nov 2019   Prob (F-statistic):           7.16e-09
# Time:                        17:06:35   Log-Likelihood:                -41871.
# No. Observations:                6403   AIC:                         8.375e+04
# Df Residuals:                    6401   BIC:                         8.376e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              328.1539     28.711     11.430      0.000     271.871     384.437
# review_scores_rating    -1.7427      0.301     -5.795      0.000      -2.332      -1.153
# ==============================================================================
# Omnibus:                     8578.624   Durbin-Watson:                   1.339
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4714239.253
# Skew:                           7.232   Prob(JB):                         0.00
# Kurtosis:                     135.140   Cond. No.                     1.31e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
test = data[['price', 'review_scores_accuracy']]
test.dropna()

m = smf.ols(formula = 'price ~ review_scores_accuracy', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     57.09
# Date:                Sat, 30 Nov 2019   Prob (F-statistic):           4.74e-14
# Time:                        17:11:59   Log-Likelihood:                -41847.
# No. Observations:                6401   AIC:                         8.370e+04
# Df Residuals:                    6399   BIC:                         8.371e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                376.9357     28.491     13.230      0.000     321.084     432.787
# review_scores_accuracy   -22.0502      2.918     -7.556      0.000     -27.771     -16.329
# ==============================================================================
# Omnibus:                     8571.216   Durbin-Watson:                   1.339
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4690142.021
# Skew:                           7.226   Prob(JB):                         0.00
# Kurtosis:                     134.820   Cond. No.                         135.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.scatter(test.review_scores_accuracy, np.log(test.price))
# Out:
# D:\Conda\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(test.review_scores_accuracy, test.price)

# %%
test = data[['price', 'latitude']]
test.dropna()

m = smf.ols(formula = 'price ~ latitude', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     16.78
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           4.25e-05
# Time:                        08:37:29   Log-Likelihood:                -50449.
# No. Observations:                7540   AIC:                         1.009e+05
# Df Residuals:                    7538   BIC:                         1.009e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9822.9992   2356.653      4.168      0.000    5203.302    1.44e+04
# latitude    -202.6857     49.483     -4.096      0.000    -299.686    -105.685
# ==============================================================================
# Omnibus:                    10862.148   Durbin-Watson:                   1.296
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7436664.779
# Skew:                           8.317   Prob(JB):                         0.00
# Kurtosis:                     155.952   Cond. No.                     5.00e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
test = data[['price', 'longitude']]
test.dropna()

m = smf.ols(formula = 'price ~ longitude', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     27.22
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           1.87e-07
# Time:                        08:38:19   Log-Likelihood:                -50444.
# No. Observations:                7540   AIC:                         1.009e+05
# Df Residuals:                    7538   BIC:                         1.009e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4.512e+04   8681.687     -5.197      0.000   -6.21e+04   -2.81e+04
# longitude   -370.2334     70.967     -5.217      0.000    -509.349    -231.118
# ==============================================================================
# Omnibus:                    10865.346   Durbin-Watson:                   1.299
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7437935.430
# Skew:                           8.322   Prob(JB):                         0.00
# Kurtosis:                     155.964   Cond. No.                     4.74e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
test = data[['price', 'property_type']]
test.dropna()

m = smf.ols(formula = 'price ~ property_type', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     11.23
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           4.71e-49
# Time:                        08:40:05   Log-Likelihood:                -50303.
# No. Observations:                7540   AIC:                         1.007e+05
# Df Residuals:                    7511   BIC:                         1.009e+05
# Df Model:                          28
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept
#       host_is_superhost  host_total_listings_count  latitude  longitude  \
# 856                   1                        1.0  47.63053 -122.36617
# 2197                  1                        8.0  47.72765 -122.33712
# 3640                  1                        4.0  47.63082 -122.36896
# 5176                  0                        1.0  47.62121 -122.29384
# 5327                  0                        1.0  47.63046 -122.36744
# 6663                  1                        2.0  47.55228 -122.32688
#
#      is_location_exact property_type        room_type  accommodates  \
# 856                  t   Guest suite  Entire home/apt             2
# 2197                 t         House     Private room             1
# 3640                 t     Townhouse  Entire home/apt            16
# 5176                 t     Townhouse  Entire home/apt             6
# 5327                 f         House  Entire home/apt             6
# 6663                 t        Castle  Entire home/apt            16
#
#       bathrooms  bedrooms  beds  bed_type   price security_deposit  \
# 856         1.0       1.0   1.0  Real Bed  3000.0              NaN
# 2197        1.0       1.0   1.0  Real Bed  5000.0          $888.00
# 3640        6.0       8.0  10.0  Real Bed  1650.0        $1,000.00
# 5176        2.5       3.0   3.0  Real Bed  5400.0        $2,000.00
# 5327        1.0       5.0   6.0  Real Bed  4000.0          $500.00
# 6663        3.0       0.0   1.0  Real Bed  2000.0          $500.00
#
#      cleaning_fee  guests_included extra_people  minimum_nights  \
# 856        $40.00                1       $30.00               2
# 2197       $30.00                1       $30.00               2
# 3640      $350.00                1        $0.00               2
# 5176      $350.00                1        $0.00               7
# 5327      $125.00                1        $0.00               1
# 6663      $150.00                1        $0.00               1
#
#       maximum_nights  number_of_reviews  number_of_reviews_ltm  \
# 856               14                 42                      1
# 2197            1125                 32                      3
# 3640            1125                  9                      6
# 5176            1125                  0                      0
# 5327              30                  0                      0
# 6663              31                  0                      0
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 856                   96.0                    10.0                       10.0
# 2197                  94.0                     9.0                        9.0
# 3640                  98.0                     9.0                        9.0
# 5176                   NaN                     NaN                        NaN
# 5327                   NaN                     NaN                        NaN
# 6663                   NaN                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 856                    10.0                         10.0
# 2197                   10.0                         10.0
# 3640                    9.0                         10.0
# 5176                    NaN                          NaN
# 5327                    NaN                          NaN
# 6663                    NaN                          NaN
#
#       review_scores_location  review_scores_value instant_bookable  \
# 856                     10.0                  9.0                t
# 2197                     9.0                  9.0                f
# 3640                    10.0                  9.0                t
# 5176                     NaN                  NaN                f
# 5327                     NaN                  NaN                t
# 6663                     NaN                  NaN                f
#
#               cancellation_policy require_guest_profile_picture  \
# 856   strict_14_with_grace_period                             f
# 2197  strict_14_with_grace_period                             f
# 3640  strict_14_with_grace_period                             f
# 5176  strict_14_with_grace_period                             f
# 5327  strict_14_with_grace_period                             f
# 6663                     moderate                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 856                                 f                               1
# 2197                                f                               3
# 3640                                f                               4
# 5176                                f                               1
# 5327                                f                               1
# 6663                                f                               1
#
#       reviews_per_month  poutlier
# 856                0.81      True
# 2197               0.84      True
# 3640               0.37      True
# 5176                NaN      True
# 5327                NaN      True
# 6663                NaN      True

# %%
# Out:
# 6
