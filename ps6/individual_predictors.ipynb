# %%
# %run initial_data_cleaning.ipynb

import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
test = data[['price', 'bedrooms']]
test = test.dropna()

m = smf.ols(formula = 'price ~ bedrooms', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     697.3
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):          4.72e-147
# Time:                        10:03:46   Log-Likelihood:                -50118.
# No. Observations:                7539   AIC:                         1.002e+05
# Df Residuals:                    7537   BIC:                         1.003e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     93.3393      3.613     25.837      0.000      86.258     100.421
# ...

# %%
test = data[['price', 'host_is_superhost']]
test = test.dropna()

m = smf.ols(formula = 'price ~ host_is_superhost', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     95.59
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           1.92e-22
# Time:                        10:04:36   Log-Likelihood:                -50410.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7538   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'bedrooms', 'host_is_superhost']]
test = test.dropna()

m = smf.ols(formula = 'price ~ host_is_superhost  + bedrooms ', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     403.1
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):          4.73e-167
# Time:                        10:03:46   Log-Likelihood:                -50068.
# No. Observations:                7539   AIC:                         1.001e+05
# Df Residuals:                    7536   BIC:                         1.002e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'beds']]
test = test.dropna()

m = smf.ols(formula = 'price ~ beds', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     453.7
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           8.12e-98
# Time:                        10:03:46   Log-Likelihood:                -50218.
# No. Observations:                7537   AIC:                         1.004e+05
# Df Residuals:                    7535   BIC:                         1.005e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    113.2235      3.446     32.854      0.000     106.468     119.979
# ...

# %%
test = data[['price', 'review_scores_rating']]
test = test.dropna()

m = smf.ols(formula = 'price ~ review_scores_rating', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           7.16e-09
# Time:                        10:03:46   Log-Likelihood:                -41871.
# No. Observations:                6403   AIC:                         8.375e+04
# Df Residuals:                    6401   BIC:                         8.376e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'review_scores_accuracy']]
test.dropna()

m = smf.ols(formula = 'price ~ review_scores_accuracy', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     57.09
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           4.74e-14
# Time:                        10:03:46   Log-Likelihood:                -41847.
# No. Observations:                6401   AIC:                         8.370e+04
# Df Residuals:                    6399   BIC:                         8.371e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(test.review_scores_accuracy, np.log(test.price))
# Out:
# D:\Conda\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(test.review_scores_accuracy, test.price)

# %%
test = data[['price', 'latitude']]
test.dropna()

m = smf.ols(formula = 'price ~ latitude', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     16.78
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           4.25e-05
# Time:                        10:03:46   Log-Likelihood:                -50449.
# No. Observations:                7540   AIC:                         1.009e+05
# Df Residuals:                    7538   BIC:                         1.009e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9822.9992   2356.653      4.168      0.000    5203.302    1.44e+04
# ...

# %%
test = data[['price', 'longitude']]
test.dropna()

m = smf.ols(formula = 'price ~ longitude', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     27.22
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           1.87e-07
# Time:                        10:03:46   Log-Likelihood:                -50444.
# No. Observations:                7540   AIC:                         1.009e+05
# Df Residuals:                    7538   BIC:                         1.009e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4.512e+04   8681.687     -5.197      0.000   -6.21e+04   -2.81e+04
# ...

# %%
test = data[['price', 'property_type']]
test = test.dropna()

m = smf.ols(formula = 'price ~ property_type -1', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     33.81
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           2.90e-34
# Time:                        10:03:46   Log-Likelihood:                -50374.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7534   BIC:                         1.008e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'cleaning_fee']]
test = test.dropna()

m = smf.ols(formula = 'price ~ cleaning_fee', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     727.1
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):          2.69e-152
# Time:                        10:03:46   Log-Likelihood:                -45696.
# No. Observations:                6849   AIC:                         9.140e+04
# Df Residuals:                    6847   BIC:                         9.141e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'security_deposit']]
test = test.dropna()

m = smf.ols(formula = 'price ~ security_deposit', data = test).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     74.63
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           7.12e-18
# Time:                        10:03:46   Log-Likelihood:                -41821.
# No. Observations:                6208   AIC:                         8.365e+04
# Df Residuals:                    6206   BIC:                         8.366e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'host_response_time']]

m = smf.ols(formula = 'price ~ host_response_time', data = test, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     6.885
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):            0.00872
# Time:                        10:12:34   Log-Likelihood:                -40456.
# No. Observations:                6056   AIC:                         8.092e+04
# Df Residuals:                    6054   BIC:                         8.093e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'reviews_per_month']]

m = smf.ols(formula = 'price ~ reviews_per_month', data = test, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     208.9
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           1.30e-46
# Time:                        10:14:25   Log-Likelihood:                -42121.
# No. Observations:                6453   AIC:                         8.425e+04
# Df Residuals:                    6451   BIC:                         8.426e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'review_scores_checkin']]

m = smf.ols(formula = 'price ~ review_scores_checkin', data = test, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     101.9
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           8.82e-24
# Time:                        10:16:27   Log-Likelihood:                -41818.
# No. Observations:                6400   AIC:                         8.364e+04
# Df Residuals:                    6398   BIC:                         8.365e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'review_scores_communication']]

m = smf.ols(formula = 'price ~ review_scores_communication', data = test, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     81.29
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           2.53e-19
# Time:                        10:17:57   Log-Likelihood:                -41841.
# No. Observations:                6402   AIC:                         8.369e+04
# Df Residuals:                    6400   BIC:                         8.370e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'review_scores_value']]

m = smf.ols(formula = 'price ~ review_scores_value', data = test, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     70.45
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           5.74e-17
# Time:                        10:17:35   Log-Likelihood:                -41840.
# No. Observations:                6401   AIC:                         8.368e+04
# Df Residuals:                    6399   BIC:                         8.370e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
test = data[['price', 'instant_bookable']]

m = smf.ols(formula = 'price ~ instant_bookable', data = test, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     117.5
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           3.60e-27
# Time:                        10:21:17   Log-Likelihood:                -50399.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7538   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ number_of_reviews', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     152.8
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           9.16e-35
# Time:                        10:23:57   Log-Likelihood:                -50382.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7538   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ cancellation_policy', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     389.9
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           1.17e-84
# Time:                        10:31:17   Log-Likelihood:                -50268.
# No. Observations:                7540   AIC:                         1.005e+05
# Df Residuals:                    7538   BIC:                         1.006e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ accommodates', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     919.0
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):          1.38e-190
# Time:                        10:33:07   Log-Likelihood:                -50024.
# No. Observations:                7540   AIC:                         1.001e+05
# Df Residuals:                    7538   BIC:                         1.001e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ bathrooms', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     403.9
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           1.51e-87
# Time:                        10:33:43   Log-Likelihood:                -50261.
# No. Observations:                7540   AIC:                         1.005e+05
# Df Residuals:                    7538   BIC:                         1.005e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     82.4084      4.878     16.895      0.000      72.847      91.970
# ...

# %%
m = smf.ols(formula = 'price ~ room_type -1', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     175.8
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):          3.75e-110
# Time:                        10:34:58   Log-Likelihood:                -50203.
# No. Observations:                7540   AIC:                         1.004e+05
# Df Residuals:                    7536   BIC:                         1.004e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ minimum_nights', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.520
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):             0.0335
# Time:                        10:36:48   Log-Likelihood:                -50455.
# No. Observations:                7540   AIC:                         1.009e+05
# Df Residuals:                    7538   BIC:                         1.009e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ maximum_nights', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     99.00
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           3.51e-23
# Time:                        10:37:05   Log-Likelihood:                -50408.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7538   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ number_of_reviews_ltm', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     151.1
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           2.16e-34
# Time:                        10:38:03   Log-Likelihood:                -50383.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7538   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ calculated_host_listings_count', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     143.0
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):           1.19e-32
# Time:                        10:39:49   Log-Likelihood:                -50387.
# No. Observations:                7540   AIC:                         1.008e+05
# Df Residuals:                    7538   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ host_total_listings_count', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     1162.
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):          5.70e-237
# Time:                        10:40:37   Log-Likelihood:                -49910.
# No. Observations:                7539   AIC:                         9.982e+04
# Df Residuals:                    7537   BIC:                         9.984e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ guests_included', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     530.8
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):          1.50e-113
# Time:                        10:41:32   Log-Likelihood:                -50201.
# No. Observations:                7540   AIC:                         1.004e+05
# Df Residuals:                    7538   BIC:                         1.004e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
m = smf.ols(formula = 'price ~ extra_people', data = data, missing='drop').fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.6113
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):              0.434
# Time:                        10:42:56   Log-Likelihood:                -50457.
# No. Observations:                7540   AIC:                         1.009e+05
# Df Residuals:                    7538   BIC:                         1.009e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
