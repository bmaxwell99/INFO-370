# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8fbe4ae84dae> in <module>
# ----> 1 getcwd
#
# NameError: name 'getcwd' is not defined

# %%
flights = pd.read_csv('C:/Users/dark_/Documents/INFO370/nycflights13.csv.bz2', sep = '\t')
flights.head(3)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z

# %%
flights.iloc[2]
#serial is confusing
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 2  2013      1    1     542.0             540        2.0     923.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
#
#    distance  hour  minute             time_hour
# 2      1089     5      40  2013-01-01T10:00:00Z

# %%
flights.iloc[[2]]
#as list and therefore df

# %%
flights.iloc[:3]
#first three rows
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z

# %%
flights.iloc[:3,:3]
#first three rows and first three columns
# Out:
#    year  month  day
# 0  2013      1    1
# 1  2013      1    1
# 2  2013      1    1

# %%
flights.loc[:3, ['month']]
#first three rows
# Out:
#    month
# 0      1
# 1      1
# 2      1
# 3      1

# %%
titanic = pd.read_csv('C:/Users/dark_/Documents/INFO370/titanic.csv.bz2')

# %%
titanic.iloc[[1000]]
# Out:
#       pclass  survived                          name   sex  age  sibsp  parch  \
# 1000       3         1  McCormack, Mr. Thomas Joseph  male  NaN      0      0
#
#       ticket  fare cabin embarked boat  body home.dest
# 1000  367228  7.75   NaN        Q  NaN   NaN       NaN

# %%
#grouped operations
flights.groupby('origin').origin.count()
# Out:
# origin
# EWR    120835
# JFK    111279
# LGA    104662
# Name: origin, dtype: int64

# %%
titanic.groupby('sex').sex.count()
# Out:
# sex
# female    466
# male      843
# Name: sex, dtype: int64
